# %%
import nltk

nltk.download("stopwords")
nltk.download("punkt")
nltk.download("wordnet")
nltk.download("omw-1.4")
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\Asus\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping corpora\stopwords.zip.
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\Asus\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping tokenizers\punkt.zip.
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\Asus\AppData\Roaming\nltk_data...
# [nltk_data] Downloading package omw-1.4 to
# [nltk_data]     C:\Users\Asus\AppData\Roaming\nltk_data...
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[1], line 6
#       2
#       3 nltk.download("stopwords")
#       4 nltk.download("punkt")
#       5 nltk.download("wordnet")
# ----> 6 nltk.download("omw-1.4")
#
# ...

# %%
import nltk

print(nltk.data.path)
# Out:
# ['C:\\Users\\Asus/nltk_data', 'c:\\Users\\Asus\\NLP_Group_19\\venv\\nltk_data', 'c:\\Users\\Asus\\NLP_Group_19\\venv\\share\\nltk_data', 'c:\\Users\\Asus\\NLP_Group_19\\venv\\lib\\nltk_data', 'C:\\Users\\Asus\\AppData\\Roaming\\nltk_data', 'C:\\nltk_data', 'D:\\nltk_data', 'E:\\nltk_data']

# %%
import nltk

resources = [
    "stopwords",
    "punkt",
    "wordnet",
    "omw-1.4"
]

for resource in resources:
    try:
        nltk.data.find(resource)
        print(resource, "Available ✅")
    except:
        print(resource, "Missing ❌")
# Out:
# stopwords Missing ❌
# punkt Missing ❌
# wordnet Missing ❌
# omw-1.4 Missing ❌

# %%
import nltk

print(nltk.data.path)
# Out:
# ['C:\\Users\\Asus/nltk_data', 'c:\\Users\\Asus\\NLP_Group_19\\venv\\nltk_data', 'c:\\Users\\Asus\\NLP_Group_19\\venv\\share\\nltk_data', 'c:\\Users\\Asus\\NLP_Group_19\\venv\\lib\\nltk_data', 'C:\\Users\\Asus\\AppData\\Roaming\\nltk_data', 'C:\\nltk_data', 'D:\\nltk_data', 'E:\\nltk_data']

# %%
import nltk

nltk.download("stopwords")
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\Asus\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
nltk.download("punkt")
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\Asus\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %%
nltk.download("wordnet")
# Out:
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\Asus\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# True

# %%
nltk.download("omw-1.4")
# Out:
# [nltk_data] Downloading package omw-1.4 to
# [nltk_data]     C:\Users\Asus\AppData\Roaming\nltk_data...
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 nltk.download("omw-1.4")
#
# File c:\Users\Asus\NLP_Group_19\venv\Lib\site-packages\nltk\downloader.py:1031, in Downloader.download(self, info_or_id, download_dir, quiet, force, prefix, halt_on_error, raise_on_error, print_error_to, hf)
#    1022 def show(s, prefix2=""):
#    1023     print_to(
#    1024         textwrap.fill(
#    1025             s,
#    (...)   1028         )
#    1029     )
# -> 1031 for msg in self.incr_download(info_or_id, download_dir, force):
#    1032     # Error messages
#    1033     if isinstance(msg, ErrorMessage):
#    1034         show(msg.message)
#
# ...

# %%
import nltk

resources = [
    "stopwords",
    "punkt",
    "wordnet"
]

for resource in resources:
    try:
        nltk.data.find(resource)
        print(resource, "Available ✅")
    except:
        print(resource, "Missing ❌")
# Out:
# stopwords Missing ❌
# punkt Missing ❌
# wordnet Missing ❌

# %%
import nltk
nltk.download()
# Out:
# showing info https://raw.githubusercontent.com/nltk/nltk_data/gh-pages/index.xml
# True

# %%
import nltk

for resource in ["stopwords", "punkt", "wordnet"]:
    try:
        nltk.data.find(resource)
        print(resource, "Available ✅")
    except:
        print(resource, "Missing ❌")
# Out:
# stopwords Missing ❌
# punkt Missing ❌
# wordnet Missing ❌

# %%
import nltk

print(nltk.data.path)
# Out:
# ['C:\\Users\\Asus/nltk_data', 'c:\\Users\\Asus\\NLP_Group_19\\venv\\nltk_data', 'c:\\Users\\Asus\\NLP_Group_19\\venv\\share\\nltk_data', 'c:\\Users\\Asus\\NLP_Group_19\\venv\\lib\\nltk_data', 'C:\\Users\\Asus\\AppData\\Roaming\\nltk_data', 'C:\\nltk_data', 'D:\\nltk_data', 'E:\\nltk_data']

# %%
import nltk

nltk.data.path.append(
    r"C:\Users\Asus\AppData\Roaming\nltk_data"
)

for resource in ["stopwords", "punkt", "wordnet"]:
    try:
        nltk.data.find(resource)
        print(resource, "Available ✅")
    except:
        print(resource, "Missing ❌")
# Out:
# stopwords Missing ❌
# punkt Missing ❌
# wordnet Missing ❌

# %%
import nltk
nltk.download("stopwords", download_dir=r"C:\Users\Asus\AppData\Roaming\nltk_data")
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\Asus\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
nltk.download("punkt", download_dir=r"C:\Users\Asus\AppData\Roaming\nltk_data")
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\Asus\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %%
nltk.download("wordnet", download_dir=r"C:\Users\Asus\AppData\Roaming\nltk_data")
# Out:
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\Asus\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# True

# %%
import nltk

resources = {
    "stopwords": "corpora/stopwords",
    "punkt": "tokenizers/punkt",
    "wordnet": "corpora/wordnet"
}

for name, path in resources.items():
    try:
        nltk.data.find(path)
        print(name, "Available ✅")
    except LookupError:
        print(name, "Missing ❌")
# Out:
# stopwords Available ✅
# punkt Available ✅
# wordnet Missing ❌

# %%
import nltk

nltk.download(
    "wordnet",
    download_dir=r"C:\Users\Asus\AppData\Roaming\nltk_data"
)
# Out:
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\Asus\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# True

# %%
import nltk

resources = {
    "stopwords": "corpora/stopwords",
    "punkt": "tokenizers/punkt",
    "wordnet": "corpora/wordnet"
}

for name, path in resources.items():
    try:
        nltk.data.find(path)
        print(name, "Available ✅")
    except LookupError:
        print(name, "Missing ❌")
# Out:
# stopwords Available ✅
# punkt Available ✅
# wordnet Missing ❌

# %%
nltk.download("omw-1.4")
# Out:
# [nltk_data] Downloading package omw-1.4 to
# [nltk_data]     C:\Users\Asus\AppData\Roaming\nltk_data...
# True

# %%
import nltk

resources = {
    "stopwords": "corpora/stopwords",
    "punkt": "tokenizers/punkt",
    "wordnet": "corpora/wordnet"
}

for name, path in resources.items():
    try:
        nltk.data.find(path)
        print(name, "Available ✅")
    except LookupError:
        print(name, "Missing ❌")
# Out:
# stopwords Available ✅
# punkt Available ✅
# wordnet Missing ❌

# %%
import nltk

nltk.download(
    "wordnet",
    download_dir=r"C:\Users\Asus\AppData\Roaming\nltk_data",
    force=True
)
# Out:
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\Asus\AppData\Roaming\nltk_data...
# True

# %%
import os

path = r"C:\Users\Asus\AppData\Roaming\nltk_data\corpora"

print(os.listdir(path))
# Out:
# ['abc', 'abc.zip', 'omw-1.4.zip', 'stopwords', 'stopwords.zip', 'wordnet.zip']

# %%
import nltk

resources = {
    "stopwords": "corpora/stopwords",
    "punkt": "tokenizers/punkt",
    "wordnet": "corpora/wordnet"
}

for name, path in resources.items():
    try:
        nltk.data.find(path)
        print(name, "Available ✅")
    except LookupError:
        print(name, "Missing ❌")
# Out:
# stopwords Available ✅
# punkt Available ✅
# wordnet Missing ❌

# %%
import nltk

resources = {
    "stopwords": "corpora/stopwords",
    "punkt": "tokenizers/punkt",
    "wordnet": "corpora/wordnet"
}

for name, path in resources.items():
    try:
        nltk.data.find(path)
        print(name, "Available ✅")
    except LookupError:
        print(name, "Missing ❌")
# Out:
# stopwords Available ✅
# punkt Available ✅
# wordnet Available ✅
